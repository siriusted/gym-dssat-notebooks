# %% [markdown]
# <a href="https://colab.research.google.com/github/siriusted/gym-dssat-notebooks/blob/master/SB3_example_with_env_vars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gym-DSSAT x Stable-Baselines3 Tutorial
#
# Welcome to a brief introduction to using gym-dssat with stable-baselines3.
#
# For a background or more details about using stable-baselines3 for reinforcement learning, please take a look [here](https://github.com/araffin/rl-tutorial-jnrr19/tree/sb3)
#
# In this notebook, we will assume familiarity with reinforcement learning and stable-baselines3. Thus the focus is on interacting with gym-dssat using SB3.
#
# Next we proceed with installations
#
# **Note**: It will take a while
#
# # Installation
# - gym_dssat

# %%
# !wget https://raw.githubusercontent.com/siriusted/gym-dssat-notebooks/master/install.sh
# !chmod u+x install.sh
# Out:
# --2022-02-22 12:25:49--  https://raw.githubusercontent.com/siriusted/gym-dssat-notebooks/master/install.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2162 (2.1K) [text/plain]
# Saving to: ‘install.sh’
#
# install.sh          100%[===================>]   2.11K  --.-KB/s    in 0s
#
# 2022-02-22 12:25:49 (31.0 MB/s) - ‘install.sh’ saved [2162/2162]

# %%
# !./install.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:325:9:
#
#      real  hex_min                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:326:9:
#
#      real  hour                                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:327:9:
#
#      real  ini_dw_lf_phy                               !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:328:9:
#
#      real  ini_la                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:329:9:
#
#      real  init_leaf_area                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:330:9:
#
#      real  it_struc_pfac                               !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:331:9:
#
#      real  it_struc_pfac_delta                         !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:332:9:
#
#      real  it_struc_pfac_max                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:333:9:
#
#      real  it_struc_pfac_min                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:334:9:
#
#      real  it_struc_pfac_rate                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:335:9:
#
#      real  it_struc_pfac_tb                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:336:9:
#
#      real  it_struc_pfac_te                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:337:9:
#
#      real  it_struc_pfac_temp_max_red                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:338:9:
#
#      real  it_struc_pfac_tm                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:339:9:
#
#      real  it_struc_pfac_wate_max_red                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:340:9:
#
#      real  it_struc_tb_end                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:341:9:
#
#      real  it_struc_tb_ini                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:342:9:
#
#      real  it_struc_to1                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:343:9:
#
#      real  it_struc_to2                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:344:9:
#
#      real  k                                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:345:9:
#
#      real  kmr_it_phy                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:346:9:
#
#      real  kmr_leaf                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:347:9:
#
#      real  kmr_root                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:348:9:
#
#      real  kmr_stem                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:349:9:
#
#      real  kmr_stor                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:350:9:
#
#      real  la_lf_shed_phy                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:351:9:
#
#      real  lai_ass                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:352:9:
#
#      real  laimod                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:353:9:
#
#      real  lf_dpos                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:354:9:
#
#      real  lgpf                                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:355:9:
#
#      real  lt                                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:356:9:
#
#      real  ltthreshold                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:357:9:
#
#      real  maintenance_factor_crop                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:358:9:
#
#      real  maintenance_factor_it                       !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:359:9:
#
#      real  maintenance_factor_it_ag                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:360:9:
#
#      real  maintenance_factor_it_bg                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:361:9:
#
#      real  maintenance_factor_it_phy                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:362:9:
#
#      real  maintenance_factor_lf                       !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:363:9:
#
#      real  maintenance_factor_lf_phy                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:364:9:
#
#      real  maintenance_factor_rt                       !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:365:9:
#
#      real  max_ini_la                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:366:9:
#
#      real  max_it_dw                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:367:9:
#
#      real  max_it_dw_bg                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:368:9:
#
#      real  max_it_dw_phy                               !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:369:9:
#
#      real  max_per_it                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:370:9:
#
#      real  mid_tt_it_growth                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:371:9:
#
#      real  mid_tt_lf_growth                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:372:9:
#
#      real  mid_tt_rt_growth                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:373:9:
#
#      real  mresp_it                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:374:9:
#
#      real  mresp_it_phy                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:375:9:
#
#      real  mresp_lf                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:376:9:
#
#      real  mresp_lf_phy                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:377:9:
#
#      real  mresp_rt                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:378:9:
#
#      real  n_lf_max_ini_la                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:379:9:
#
#      real  n_lf_tiller                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:380:9:
#
#      real  nsenesleaf_effect                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:381:9:
#
#      real  nstk_at_appearance                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:382:9:
#
#      real  nstk_now                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:383:9:
#
#      real  par_rad                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:384:9:
#
#      real  per                                         !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:385:9:
#
#      real  per_hour                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:386:9:
#
#      real  per_it_phy                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:387:9:
#
#      real  pho_fac_co2                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:388:9:
#
#      real  phy_stimuli                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:389:9:
#
#      real  phyllochron                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:390:9:
#
#      real  plastochron                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:391:9:
#
#      real  poppeak_lt                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:392:9:
#
#      real  q10_it_phy                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:393:9:
#
#      real  q10_leaf                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:394:9:
#
#      real  q10_root                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:395:9:
#
#      real  q10_stem                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:396:9:
#
#      real  q10_stor                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:397:9:
#
#      real  rdprof                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:398:9:
#
#      real  reduc_growth_factor_crop                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:399:9:
#
#      real  reduc_growth_factor_it                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:400:9:
#
#      real  reduc_growth_factor_it_ag                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:401:9:
#
#      real  reduc_growth_factor_it_bg                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:402:9:
#
#      real  reduc_growth_factor_it_phy                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:403:9:
#
#      real  reduc_growth_factor_lf                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:404:9:
#
#      real  reduc_growth_factor_lf_phy                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:405:9:
#
#      real  reduc_growth_factor_rt                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:406:9:
#
#      real  rel_ss_it_phy                               !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:407:9:
#
#      real  rel_ss_lf_phy                               !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:408:9:
#
#      real  res_used_emerg                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:409:9:
#
#      real  res_used_emerg_fac                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:410:9:
#
#      real  reserves_used_growth_it                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:411:9:
#
#      real  reserves_used_growth_lf                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:412:9:
#
#      real  reserves_used_growth_rt                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:413:9:
#
#      real  reserves_used_mresp_crop                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:414:9:
#
#      real  reserves_used_mresp_it                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:415:9:
#
#      real  reserves_used_mresp_it_ag                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:416:9:
#
#      real  reserves_used_mresp_it_bg                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:417:9:
#
#      real  reserves_used_mresp_it_phy                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:418:9:
#
#      real  reserves_used_mresp_lf                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:419:9:
#
#      real  reserves_used_mresp_lf_phy                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:420:9:
#
#      real  reserves_used_mresp_rt                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:421:9:
#
#      real  rgpf                                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:422:9:
#
#      real  root_front_size                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:423:9:
#
#      real  rootdrate                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:424:9:
#
#      real  rootshape                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:425:9:
#
#      real  rpup                                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:426:9:
#
#      real  rue_mod                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:427:9:
#
#      real  shared_it_str_bg                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:428:9:
#
#      real  shared_it_sug_bg                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:429:9:
#
#      real  shootdepth                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:430:9:
#
#      real  soiltemperature                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:431:9:
#
#      real  srlmax                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:432:9:
#
#      real  srlmin                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:433:9:
#
#      real  stk_h                                       !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:434:9:
#
#      real  str_it_ag                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:435:9:
#
#      real  str_it_phy                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:436:9:
#
#      real  subs_avail_growth_crop                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:437:9:
#
#      real  subs_avail_growth_it                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:438:9:
#
#      real  subs_avail_growth_it_ag                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:439:9:
#
#      real  subs_avail_growth_it_ag_ref_till            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:440:9:
#
#      real  subs_avail_growth_it_bg                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:441:9:
#
#      real  subs_avail_growth_it_bg_ref_till            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:442:9:
#
#      real  subs_avail_growth_it_phy                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:443:9:
#
#      real  subs_avail_growth_it_ref_till               !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:444:9:
#
#      real  subs_avail_growth_lf                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:445:9:
#
#      real  subs_avail_growth_lf_phy                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:446:9:
#
#      real  subs_avail_growth_lf_ref_till               !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:447:9:
#
#      real  subs_avail_growth_rt                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:448:9:
#
#      real  subsres                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:449:9:
#
#      real  subsres_avail_it                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:450:9:
#
#      real  subsres_avail_it_ag                         !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:451:9:
#
#      real  subsres_avail_it_ag_ref_till                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:452:9:
#
#      real  subsres_avail_it_bg                         !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:453:9:
#
#      real  subsres_avail_it_bg_ref_till                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:454:9:
#
#      real  subsres_avail_it_phy                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:455:9:
#
#      real  subsres_avail_it_ref_till                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:456:9:
#
#      real  subsres_avail_lf                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:457:9:
#
#      real  subsres_avail_lf_phy                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:458:9:
#
#      real  subsres_avail_lf_ref_till                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:459:9:
#
#      real  subsres_avail_rt                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:460:9:
#
#      real  suc_acc_ini                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:461:9:
#
#      real  suc_frac_rate_ts                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:462:9:
#
#      real  suc_it_ag                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:463:9:
#
#      real  suc_it_ag_ref_till                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:464:9:
#
#      real  suc_it_bg_ref_till                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:465:9:
#
#      real  suc_it_phy                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:466:9:
#
#      real  suc_min                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:467:9:
#
#      real  sug_cont                                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:468:9:
#
#      real  sug_it_ag                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:469:9:
#
#      real  sug_it_phy                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:470:9:
#
#      real  sup_ratio_it                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:471:9:
#
#      real  sup_ratio_it_ag                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:472:9:
#
#      real  sup_ratio_it_bg                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:473:9:
#
#      real  sup_ratio_it_phy                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:474:9:
#
#      real  sup_ratio_lf                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:475:9:
#
#      real  sup_ratio_lf_phy                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:476:9:
#
#      real  sup_ratio_rt                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:477:9:
#
#      real  supply_rate_it                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:478:9:
#
#      real  supply_rate_it_ag                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:479:9:
#
#      real  supply_rate_it_bg                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:480:9:
#
#      real  supply_rate_it_phy                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:481:9:
#
#      real  supply_rate_lf                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:482:9:
#
#      real  supply_rate_lf_phy                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:483:9:
#
#      real  supply_rate_rt                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:484:9:
#
#      real  supply_used_crop                            !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:485:9:
#
#      real  supply_used_dw_crop                         !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:486:9:
#
#      real  supply_used_dw_it                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:487:9:
#
#      real  supply_used_dw_it_ag                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:488:9:
#
#      real  supply_used_dw_it_bg                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:489:9:
#
#      real  supply_used_dw_it_phy                       !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:490:9:
#
#      real  supply_used_dw_lf                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:491:9:
#
#      real  supply_used_dw_lf_phy                       !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:492:9:
#
#      real  supply_used_dw_rt                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:493:9:
#
#      real  supply_used_gresp_crop                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:494:9:
#
#      real  supply_used_gresp_it                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:495:9:
#
#      real  supply_used_gresp_it_ag                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:496:9:
#
#      real  supply_used_gresp_it_bg                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:497:9:
#
#      real  supply_used_gresp_it_phy                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:498:9:
#
#      real  supply_used_gresp_lf                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:499:9:
#
#      real  supply_used_gresp_lf_phy                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:500:9:
#
#      real  supply_used_gresp_rt                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:501:9:
#
#      real  supply_used_it                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:502:9:
#
#      real  supply_used_it_ag                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:503:9:
#
#      real  supply_used_it_bg                           !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:504:9:
#
#      real  supply_used_it_phy                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:505:9:
#
#      real  supply_used_lf                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:506:9:
#
#      real  supply_used_lf_phy                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:507:9:
#
#      real  supply_used_mresp_crop                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:508:9:
#
#      real  supply_used_mresp_it                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:509:9:
#
#      real  supply_used_mresp_it_ag                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:510:9:
#
#      real  supply_used_mresp_it_bg                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:511:9:
#
#      real  supply_used_mresp_it_phy                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:512:9:
#
#      real  supply_used_mresp_lf                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:513:9:
#
#      real  supply_used_mresp_lf_phy                    !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:514:9:
#
#      real  supply_used_mresp_rt                        !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:515:9:
#
#      real  supply_used_rt                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:516:9:
#
#      real  t_mresp                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:517:9:
#
#      real  tb0pho                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:518:9:
#
#      real  tb1pho                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:519:9:
#
#      real  tb2pho                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:520:9:
#
#      real  tbfpho                                      !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:521:9:
#
#      real  tbmax_per                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:522:9:
#
#      real  temperature_factor                          !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:523:9:
#
#      real  tempfac_per                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:524:9:
#
#      real  tempfac_pho                                 !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:525:9:
#
#      real  tilleragefac_adjust                         !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:526:9:
#
#      real  tillochron                                  !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:527:9:
#
#      real  tot_dw_ss_crop                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:528:9:
#
#      real  tot_dw_ss_it                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:529:9:
#
#      real  tot_dw_ss_it_ag                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:530:9:
#
#      real  tot_dw_ss_it_bg                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:531:9:
#
#      real  tot_dw_ss_lf                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:532:9:
#
#      real  tot_dw_ss_rt                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:533:9:
#
#      real  tot_gresp_crop                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:534:9:
#
#      real  tot_gresp_it                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:535:9:
#
#      real  tot_gresp_it_ag                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:536:9:
#
#      real  tot_gresp_it_bg                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:537:9:
#
#      real  tot_gresp_lf                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:538:9:
#
#      real  tot_gresp_rt                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:539:9:
#
#      real  tot_mresp_crop                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:540:9:
#
#      real  tot_mresp_it                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:541:9:
#
#      real  tot_mresp_it_ag                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:542:9:
#
#      real  tot_mresp_it_bg                             !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:543:9:
#
#      real  tot_mresp_lf                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:544:9:
#
#      real  tot_mresp_rt                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:545:9:
#
#      real  tref_mr                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:546:9:
#
#      real  tref_mr_it_phy                              !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:547:9:
#
#      real  ts_it_phy                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:548:9:
#
#      real  tt_chumat_lt                                !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:549:9:
#
#      real  wat_con                                     !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:550:9:
#
#      real  wat_it_ag                                   !
#          1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:591:10:
#
#      real  AMAX
#           1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:592:10:
#
#      real  EFF
#           1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:593:10:
#
#      real  PHTMAX
#           1
# Warning: Nonconforming tab character at (1) [-Wtabs]
# /content/gym_dssat_pdi/dssat-csm-os/Plant/SAMUCA-Sugarcane/SC_SAMUCA_MODEL.f90:594:10:
#
#      real  PARMAX
#           1
# ...
#                            1
# Warning: CHARACTER expression will be truncated in assignment (12/92) at (1) [-Wcharacter-truncation]
# /content/gym_dssat_pdi/dssat-csm-os/Weather/IPWTH_alt.for:1195:40:
#
#       &    SRAD, TDEW, TMAX, TMIN, WINDSP, YRDOYW,         !Input
#                                         1
# Warning: Unused dummy argument ‘windsp’ at (1) [-Wunused-dummy-argument]
# [ 99%] Building Fortran object CMakeFiles/dscsm047.dir/Weather/OPWEATH.for.o
# [ 99%] Building Fortran object CMakeFiles/dscsm047.dir/Weather/SOLAR.for.o
# [ 99%] Building Fortran object CMakeFiles/dscsm047.dir/Weather/weathr.for.o
# [ 99%] Building Fortran object CMakeFiles/dscsm047.dir/Weather/WGEN.for.o
# /content/gym_dssat_pdi/dssat-csm-os/Weather/WGEN.for:416:0:
#
#            Y(MTH,14)  = PWW
#
# Warning: ‘pww’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# /content/gym_dssat_pdi/dssat-csm-os/Weather/WGEN.for:414:0:
#
#            Y(MTH,12)  = BETA
#
# Warning: ‘beta’ may be used uninitialized in this function [-Wmaybe-uninitialized]
# [ 99%] Building Fortran object CMakeFiles/dscsm047.dir/Weather/WTHMOD.for.o
# [100%] Linking Fortran executable bin/dscsm047
# [100%] Built target dscsm047
# [100%] Built target dscsm047
# Install the project...
# -- Install configuration: "DEBUG"
# -- Installing: /opt/dssat_pdi/./dscsm047
# -- Set runtime path of "/opt/dssat_pdi/./dscsm047" to ""
# -- Installing: /opt/dssat_pdi/./run_dssat
# -- Up-to-date: /opt/dssat_pdi/.
# -- Installing: /opt/dssat_pdi/./SIMULATION.CDE
# -- Installing: /opt/dssat_pdi/./DSSATPRO.L48
# -- Installing: /opt/dssat_pdi/./DSCSM048.CTR
# -- Installing: /opt/dssat_pdi/./DSSATPRO.v48
# -- Installing: /opt/dssat_pdi/./Genotype
# -- Installing: /opt/dssat_pdi/./Genotype/CSYCA048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/PRGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SCCSP048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/TFAPS048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/PTSUB048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/TNARO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/QUGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/RICER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PRGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BRGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/VBGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BRFRM048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/ALFRM048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BSCER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PPGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/QUGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/MZCER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/TMGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SFGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/PRGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CPGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/VBGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SCCSP048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BACER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BMGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CBGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BRFRM048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/MZIXM048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CHGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CBGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CSYCA048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BMFRM048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SUGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/TFAPS048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PNGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BNGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CIGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SCCAN048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/WHCER048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CPGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/SWCER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/PNGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BMGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BSCER048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/COGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/ALFRM048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/WHCER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/WHAPS048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BSCER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/ALFRM048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/CIGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/MZIXM048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BNGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SBGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/PPGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BACRP048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/SBGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CNGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BHGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SCCAN048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/TMGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/MZIXM048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CSCAS048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CHGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BACRP048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BMFRM048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CSCAS048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PNGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/WHAPS048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/WHCRP048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/GBGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BHGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/COGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/MLCER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CNGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/SGCER048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/QUGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/GBGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/VBGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/TMGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/WHCER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/FBGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PPGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/SCCAN048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/G0GRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SUGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SGCER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/WHCRP048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BACRP048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BACER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/GBGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/G0GRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/FBGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SGCER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/MZCER048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BACER048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/COGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/CBGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SWCER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/RICER048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/WHCRP048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PTSUB048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/SCSAM048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/G0GRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SCSAM048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SFGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/CPGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CIGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CNGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SUGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PTSUB048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PIALO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SBGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/CSCAS048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/WHAPS048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/TFAPS048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/MZCER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/MLCER048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/MLCER048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/TRARO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SCSAM048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BNGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BRGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BMGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BRGRO048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/CSYCA048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/PIALO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/TNARO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/CHGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/FBGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/BRFRM048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/SFGRO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/BMFRM048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/BHGRO048.ECO
# -- Installing: /opt/dssat_pdi/./Genotype/TRARO048.SPE
# -- Installing: /opt/dssat_pdi/./Genotype/SCCSP048.CUL
# -- Installing: /opt/dssat_pdi/./Genotype/SWCER048.ECO
# -- Installing: /opt/dssat_pdi/./DETAIL.CDE
# -- Installing: /opt/dssat_pdi/./PEST.CDE
# -- Installing: /opt/dssat_pdi/./JDATE.CDE
# -- Installing: /opt/dssat_pdi/./GRSTAGE.CDE
# -- Installing: /opt/dssat_pdi/./GCOEFF.CDE
# -- Installing: /opt/dssat_pdi/./DATA.CDE
# -- Installing: /opt/dssat_pdi/./ECONOMIC.CDE
# -- Installing: /opt/dssat_pdi/./MODEL.ERR
# -- Installing: /opt/dssat_pdi/./StandardData
# -- Installing: /opt/dssat_pdi/./StandardData/SOMFX047.SDA
# -- Installing: /opt/dssat_pdi/./StandardData/RESCH047.SDA
# -- Installing: /opt/dssat_pdi/./StandardData/SOMFR047.SDA
# -- Installing: /opt/dssat_pdi/./StandardData/TILOP047.SDA
# -- Installing: /opt/dssat_pdi/./StandardData/FERCH047.SDA
# -- Installing: /opt/dssat_pdi/./StandardData/CO2047.WDA
# -- Installing: /opt/dssat_pdi/./SOIL.CDE
# -- Installing: /opt/dssat_pdi/./OUTPUT.CDE
# -- Installing: /opt/dssat_pdi/./WEATHER.CDE
# -- Installing: /opt/dssat_pdi/./Pest
# -- Installing: /opt/dssat_pdi/./Pest/CHGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/PPGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/BRGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/MLCER048.PST
# -- Installing: /opt/dssat_pdi/./Pest/BSCER048.PST
# -- Installing: /opt/dssat_pdi/./Pest/SBGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/MZIXM048.PST
# -- Installing: /opt/dssat_pdi/./Pest/MZCER048.PST
# -- Installing: /opt/dssat_pdi/./Pest/COGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/BNGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/FBGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/QUGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/SUOIL048.PST
# -- Installing: /opt/dssat_pdi/./Pest/WHAPS048.PST
# -- Installing: /opt/dssat_pdi/./Pest/GBGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/VBGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/CPGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/CIGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/BRFRM048.PST
# -- Installing: /opt/dssat_pdi/./Pest/BHGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/PNGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/TMGRO048.PST
# -- Installing: /opt/dssat_pdi/./Pest/BMFRM048.PST
# -- Installing: /opt/dssat_pdi/./Pest/SGCER048.PST
# Done
#
# Installing gym-dssat...
# Obtaining file:///content/gym_dssat_pdi/gym-dssat-pdi
# Requirement already satisfied: gym==0.18.3 in /usr/local/lib/python3.7/dist-packages (from gym-dssat-pdi==0.0.4) (0.18.3)
# Collecting numpy==1.21.4
#   Downloading numpy-1.21.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 5.1 MB/s
# Collecting matplotlib==3.5.1
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 59.8 MB/s
# Collecting jinja2==3.0.3
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 54.8 MB/s
# Requirement already satisfied: pyzmq==22.3.0 in /usr/local/lib/python3.7/dist-packages (from gym-dssat-pdi==0.0.4) (22.3.0)
# Collecting psutil==5.9.0
#   Downloading psutil-5.9.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 58.3 MB/s
# Requirement already satisfied: pyyaml==6.0 in /usr/local/lib/python3.7/dist-packages (from gym-dssat-pdi==0.0.4) (6.0)
# Collecting six==1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.18.3->gym-dssat-pdi==0.0.4) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym==0.18.3->gym-dssat-pdi==0.0.4) (1.4.1)
# Requirement already satisfied: Pillow<=8.2.0 in /usr/local/lib/python3.7/dist-packages (from gym==0.18.3->gym-dssat-pdi==0.0.4) (7.1.2)
# Collecting cloudpickle<1.7.0,>=1.2.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from jinja2==3.0.3->gym-dssat-pdi==0.0.4) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1->gym-dssat-pdi==0.0.4) (1.3.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 63.7 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1->gym-dssat-pdi==0.0.4) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1->gym-dssat-pdi==0.0.4) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1->gym-dssat-pdi==0.0.4) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib==3.5.1->gym-dssat-pdi==0.0.4) (21.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.15,>=1.4.0->gym==0.18.3->gym-dssat-pdi==0.0.4) (0.16.0)
# Installing collected packages: six, numpy, fonttools, cloudpickle, psutil, matplotlib, jinja2, gym-dssat-pdi
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.0.0
#     Uninstalling cloudpickle-2.0.0:
#       Successfully uninstalled cloudpickle-2.0.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
#   Running setup.py develop for gym-dssat-pdi
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.0.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed cloudpickle-1.6.0 fonttools-4.29.1 gym-dssat-pdi-0.0.4 jinja2-3.0.3 matplotlib-3.5.1 numpy-1.21.4 psutil-5.9.0 six-1.16.0
# Done
#
# Installation procedure completed!

# %%
# !cd gym_dssat_pdi/ && git branch
# Out:
# * dev
#   stable

# %% [markdown]
# - stable_baselines3

# %%
# !pip install stable-baselines3[extra]
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-1.4.0-py3-none-any.whl (176 kB)
#      |████████████████████████████████| 176 kB 5.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (1.3.5)
# Requirement already satisfied: gym<0.20,>=0.17 in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (0.18.3)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (1.10.0+cu111)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (1.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (1.21.4)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (2.8.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (7.1.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (5.9.0)
# Collecting atari-py==0.2.6
#   Downloading atari_py-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 43.2 MB/s
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from stable-baselines3[extra]) (4.1.2.30)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from atari-py==0.2.6->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym<0.20,>=0.17->stable-baselines3[extra]) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym<0.20,>=0.17->stable-baselines3[extra]) (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.15,>=1.4.0->gym<0.20,>=0.17->stable-baselines3[extra]) (0.16.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.43.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (57.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.17.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->stable-baselines3[extra]) (4.11.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->stable-baselines3[extra]) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.2.0->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[extra]) (4.29.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[extra]) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->stable-baselines3[extra]) (2018.9)
# WARNING: The candidate selected for download or install is a yanked version: 'atari-py' candidate (version 0.2.6 at https://files.pythonhosted.org/packages/8f/ba/1d22e9d2f332f07aaa57041f5dd569c2cb40a92bd6374a0b743ec3dfae97/atari_py-0.2.6-cp37-cp37m-manylinux1_x86_64.whl#sha256=d9e2c25d39783867c2f29d1dd9d3a659fc56036456d07dc9efe8bd7bb31a07d7 (from https://pypi.org/simple/atari-py/))
# Reason for being yanked: re-release with new wheels
# Installing collected packages: stable-baselines3, atari-py
#   Attempting uninstall: atari-py
#     Found existing installation: atari-py 0.2.9
#     Uninstalling atari-py-0.2.9:
#       Successfully uninstalled atari-py-0.2.9
# Successfully installed atari-py-0.2.6 stable-baselines3-1.4.0

# %% [markdown]
# All set!
#
# Next, we will train a PPO agent using stable-baselines3. This agent will be compared to two hardcoded agents, namely a Null agent and an Expert agent.
#
# To use gym-dssat properly, we need to run commands using `pdirun`. As a result, the source code for the rest of the tutorial has been collected into a script, which we will fetch next, then run.

# %%
# !wget https://raw.githubusercontent.com/siriusted/gym-dssat-notebooks/master/sb_example.py

# %% [markdown]
# Run example. Note that this will take some time. You can take a look at `sb_example.py` in the file browser here on colab

# %%
# !/opt/pdi/bin/pdirun python sb_example.py > result.out

# %% [markdown]
# Next, we will load and display the results from the script which have been stored in `results.pkl`

# %%
import pickle
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

def plot_results(data):
    data_dict = {}
    for label, returns in data:
        data_dict[label] = returns
    df = pd.DataFrame(data_dict)
    
    ax = sns.boxplot(data=df)
    ax.set_xlabel("policy")
    ax.set_ylabel("evaluation output")
    plt.show()

with open("results.pkl", "rb") as result_file:
    results = pickle.load(result_file)

# %%
plot_results(results)

# %% [markdown]
# All done! Go ahead and edit `sb_example.py` in the integrated editor, then re-run the code cell above to observe results

# %%
# setup env variables like in pdirun
import os
PDI_DIR = '/opt/pdi'

os.environ['PATH'] += f'/:{PDI_DIR}/bin/'
os.environ['LD_LIBRARY_PATH'] += f'/:{PDI_DIR}/lib/'
os.environ['PYTHONPATH'] += f'/:{PDI_DIR}/lib/python3/dist-packages/'
os.environ['LIBRARY_PATH'] += f'/:{PDI_DIR}/lib/'
os.environ['CPATH'] = f'{PDI_DIR}/include/:{PDI_DIR}/lib/pdi/finclude/GNU-7.5'

# %%
# !pdirun
# Out:
# Environment loaded for PDI version 1.5.0-alpha.2022-02-18.fef10ca

# %%
import gym
import gym_dssat_pdi
import random
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecCheckNan
from stable_baselines3.common.callbacks import EvalCallback
torch.autograd.set_detect_anomaly(True)

# %%
# helpers for action normalization
def normalize_action(action_space_limits, action):
    """Normalize the action from [low, high] to [-1, 1]"""
    low, high = action_space_limits
    return 2.0 * ((action - low) / (high - low)) - 1.0

def denormalize_action(action_space_limits, action):
    """Denormalize the action from [-1, 1] to [low, high]"""
    low, high = action_space_limits
    return low + (0.5 * (action + 1.0) * (high - low))

# Wrapper for easy and uniform interfacing with SB3
class GymDssatWrapper(gym.Wrapper):
    def __init__(self, env):
        super(GymDssatWrapper, self).__init__(env)

        self.action_low, self.action_high = self._get_action_space_bounds()

        # using a normalized action space
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(1,), dtype="float32")

        # using a vector representation of observations to allow
        # easily using SB3 MlpPolicy
        self.observation_space = gym.spaces.Box(low=0.0,
                                                high=np.inf,
                                                shape=env.observation_dict_to_array(
                                                    env.observation).shape,
                                                dtype="float32"
                                                )

        # to avoid annoying problem with Monitor when episodes end and things are None
        self.last_info = {}
        self.last_obs = None

    def _get_action_space_bounds(self):
        box = self.env.action_space['anfer']
        return box.low, box.high

    def _format_action(self, action):
        return { 'anfer': action[0] }

    def _format_observation(self, observation):
        return self.env.observation_dict_to_array(observation)

    def reset(self):
        return self._format_observation(self.env.reset())


    def step(self, action):
        # Rescale action from [-1, 1] to original action space interval
        denormalized_action = denormalize_action((self.action_low, self.action_high), action)
        formatted_action = self._format_action(denormalized_action)
        obs, reward, done, info = self.env.step(formatted_action)

        # handle `None`s in obs, reward, and info on done step
        if done:
            obs, reward, info = self.last_obs, 0, self.last_info
        else:
            self.last_obs = obs
            self.last_info = info

        formatted_observation = self._format_observation(obs)
        return formatted_observation, reward, done, info

    def close(self):
        return self.env.close()

    def seed(self, seed):
        self.env.set_seed(seed)

    def eval(self):
        self.env.set_evaluation()


    def __del__(self):
        self.close()

# %%
# Create environment
env_args = {
    'run_dssat_location': '/opt/dssat_pdi/run_dssat',
    'mode': 'fertilization',
    'seed': 123,
    'random_weather': True,
}

env = Monitor(GymDssatWrapper(gym.make('GymDssatPdi-v0', **env_args)))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py in spec(self, path)
#     120         try:
# --> 121             return self.env_specs[id]
#     122         except KeyError:
#
# KeyError: 'GymDssatPdi-v0'
#
# During handling of the above exception, another exception occurred:
#
# UnregisteredEnv                           Traceback (most recent call last)
# <ipython-input-24-601fb106fba0> in <module>()
#       7 }
#       8
# ----> 9 env = Monitor(GymDssatWrapper(gym.make('GymDssatPdi-v0', **env_args)))
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py in make(id, **kwargs)
#     143
#     144 def make(id, **kwargs):
# --> 145     return registry.make(id, **kwargs)
#     146
#     147 def spec(id):
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py in make(self, path, **kwargs)
#      87         else:
#      88             logger.info('Making new env: %s', path)
# ---> 89         spec = self.spec(path)
#      90         env = spec.make(**kwargs)
#      91         # We used to have people override _reset/_step rather than
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/registration.py in spec(self, path)
#     129                 raise error.DeprecatedEnv('Env {} not found (valid versions include {})'.format(id, matching_envs))
#     130             else:
# --> 131                 raise error.UnregisteredEnv('No registered env with id: {}'.format(id))
#     132
#     133     def register(self, id, **kwargs):
#
# UnregisteredEnv: No registered env with id: GymDssatPdi-v0
